# %%
from skimage import io

# %%
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img
# Out:
# array([[[165, 217, 229, 255],
#         [165, 217, 229, 255],
#         [165, 217, 229, 255],
#         ...,
#         [165, 217, 229, 255],
#         [165, 217, 229, 255],
#         [165, 217, 229, 255]],
#
#        [[165, 217, 229, 255],
#         [165, 217, 229, 255],
#         [165, 217, 229, 255],
#         ...,
#         [165, 217, 229, 255],
#         [165, 217, 229, 255],
#         [165, 217, 229, 255]],
#
#        [[165, 217, 229, 255],
#         [165, 217, 229, 255],
#         [165, 217, 229, 255],
#         ...,
#         [165, 217, 229, 255],
#         [165, 217, 229, 255],
#         [165, 217, 229, 255]],
#
#        ...,
#
#        [[ 81, 139,  47, 255],
#         [ 81, 139,  47, 255],
#         [ 81, 139,  47, 255],
#         ...,
#         [ 79, 133,  46, 255],
#         [ 79, 133,  46, 255],
#         [ 79, 133,  46, 255]],
#
#        [[ 81, 139,  47, 255],
#         [ 81, 139,  47, 255],
#         [ 81, 139,  47, 255],
#         ...,
#         [ 78, 131,  45, 255],
# ...

# %%
temp = []
for i in img:
    for j in i:
        temp.append(j)

# %%
temp
# Out:
# [array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
#  array([165, 217, 229, 255], dtype=uint8),
# ...

# %%
a = [i[0] for i in temp]
sum(a)/len(a)
# Out:
# 208.94203195578527
